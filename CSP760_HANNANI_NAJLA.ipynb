# %% [markdown]
# <a href="https://colab.research.google.com/github/NajlaRafiz/video-tampering-detection/blob/main/CSP760_HANNANI_NAJLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow keras opencv-python matplotlib pandas numpy web3 kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 35.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.5/587.5 kB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.7/313.7 kB 32.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 kB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 106.6 MB/s eta 0:00:00
# ...

# %%
##Step 2: Download Dataset
### 1. Kaggle API Setup:
###   Create a Kaggle account → Go to "Account" → "Create API Token" (download kaggle.json).
###   Upload kaggle.json to Colab:

from google.colab import files
files.upload()  # Use the pop-up to upload kaggle.json

###   Once this is run, a file chooser will pop up. Select the downloaded kaggle.json.
# Out:
#      <input type="file" id="files-8c2a5abb-a8f7-4e27-b8c0-dc918a2b1eeb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c2a5abb-a8f7-4e27-b8c0-dc918a2b1eeb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
##Step 2: Download Dataset
### 2. Move and Secure the File:
###   After uploading, run this:

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
##Step 2: Download Dataset
### 3. Download Dataset:

# !kaggle datasets download -d ifeoluwapoo/tampering-on-video-dataset
# !unzip tampering-on-video-dataset.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ifeoluwapoo/tampering-on-video-dataset
# License(s): unknown
# ^C
# unzip:  cannot find or open tampering-on-video-dataset.zip, tampering-on-video-dataset.zip.zip or tampering-on-video-dataset.zip.ZIP.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ifeoluwapoo/tampering-on-video-dataset")

print("Path to dataset files:", path)
# Out:
# ...
#   2%|▏         | 544M/22.4G [00:04<03:07, 125MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6e27261d478c> in <cell line: 0>()
#       2
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("ifeoluwapoo/tampering-on-video-dataset")
#       5
#       6 print("Path to dataset files:", path)
#
# /usr/local/lib/python3.11/dist-packages/kagglehub/datasets.py in dataset_download(handle, path, force_download)
#      41     h = parse_dataset_handle(handle)
#      42     logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43     path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44     return path
#      45
#
# /usr/local/lib/python3.11/dist-packages/kagglehub/registry.py in __call__(self, *args, **kwargs)
#      26         for impl in reversed(self._impls):
# ...

# %%
# Verify download
import os
print("Dataset contents:", os.listdir("Tampering_on_encrypted_videos")[:3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-0b9e0973797a> in <cell line: 0>()
#       1 # Verify download
#       2 import os
# ----> 3 print("Dataset contents:", os.listdir("Tampering_on_encrypted_videos")[:3])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Tampering_on_encrypted_videos'

# %%
# Alternative method
# Direct download (if you have issues with Kaggle API)
# !wget https://www.kaggle.com/datasets/ifeoluwapoo/tampering-on-video-dataset # Replace with actual URL
#!unzip dataset.zip
# !unzip "archive.zip"
# Update: maybe need to rename to "archive.zip"?
# Out:
# --2025-05-15 08:22:49--  https://www.kaggle.com/datasets/ifeoluwapoo/tampering-on-video-dataset
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tampering-on-video-dataset’
#
# tampering-on-video-     [ <=>                ]  11.87K  --.-KB/s    in 0.006s
#
# 2025-05-15 08:22:49 (2.00 MB/s) - ‘tampering-on-video-dataset’ saved [12156]
#
# unzip:  cannot find or open archive.zip, archive.zip.zip or archive.zip.ZIP.

# %%
# Alternative method 2
# Upload the unzip file directly
# REMINDER: ONLY IF IT IS A SINGLE FILE, NOT FILES IN A FILE !!!!!!!!!!!!!!!!!

from google.colab import files
import os

# Use the pop-up to upload your local file named "Tampering on video dataset".
print('Please upload the file named "Tampering on video dataset":')
uploaded = files.upload()

# Check if the file "Tampering on video dataset" was uploaded
if 'Tampering on video dataset' in uploaded:
    print('"Tampering on video dataset" uploaded successfully.')
    # You can now access the file in the Colab environment.
    # For example, you can list the files in the current directory to confirm.
    print("Files in the current directory:", os.listdir("."))
else:
    print('"Tampering on video dataset" was not uploaded.')

# Now you can work with the uploaded file.
# The file content is available in the 'uploaded' dictionary,
# where keys are filenames and values are file contents as bytes.
# For example, to read the content:
# file_content = uploaded['Tampering on video dataset']
# print(f"Content of the uploaded file (first 100 bytes): {file_content[:100]}")

# If you need to process this file further, you might read it with a
# library like pandas if it's a CSV, or open it directly for reading.
# For example, if it's a text file:
# with open('Tampering on video dataset', 'r') as f:
#     content = f.read()
#     print("File content:", content)
# Out:
# Please upload the file named "Tampering on video dataset":
#      <input type="file" id="files-14c6c77c-39fb-4556-9ce0-f811d0aeef6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14c6c77c-39fb-4556-9ce0-f811d0aeef6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Alternative method 3
# Upload the zip file directly (Instead of using the Kaggle API commands (!kaggle datasets download and !unzip) and the kagglehub library, you will use google.colab.files.upload() to upload your local zip file and then use !unzip to extract its contents.)

from google.colab import files
import os

# Use the pop-up to upload your local dataset zip file. (e.g: archive.zip)
print("Please upload your dataset zip file (archive (2).zip):")
uploaded = files.upload()

# Check if 'archive.zip' was uploaded
if 'archive (2).zip' in uploaded:
    print('archive (2).zip uploaded.')
    # Unzip the uploaded file
    print("Unzipping archive.zip...")
    # !unzip "archive (2).zip"
else:
    print("archive (2).zip was not uploaded.")
# Now, list the contents of the current directory to identify the unzipped folder(s).
# Replace "Tampering_on_encrypted_videos" below with the actual name of the folder
# created after unzipping, which you can find by inspecting the output of os.listdir(".")
print("Contents of current directory after unzipping:", os.listdir("."))

# Example of how to verify the download (replace with actual folder name)
# print("Dataset contents:", os.listdir("YOUR_UNZIPPED_FOLDER_NAME")[:3])

#----------------------------------------------------------------------------------
## OTHER METHOD IS AS BELOW:
# Assuming you uploaded one file, get its filename
#for filename in uploaded.keys():
#  print(f'User uploaded file "{filename}" with length {len(uploaded[filename])} bytes')
#  zip_filename = filename # Store the name of the uploaded zip file

# Unzip the uploaded file
#if 'zip_filename' in locals():
#    print(f"Unzipping {zip_filename}...")
#    !unzip "{zip_filename}"
#else:
#    print("No zip file was uploaded.")

# Now, list the contents of the current directory to identify the unzipped folder(s).
# Replace "Tampering_on_encrypted_videos" below with the actual name of the folder
# created after unzipping, which you can find by inspecting the output of os.listdir(".")
print("Contents of current directory after unzipping:", os.listdir("."))

# Example of how to verify the download (replace with actual folder name)
# print("Dataset contents:", os.listdir("YOUR_UNZIPPED_FOLDER_NAME")[:3])
# Out:
# Please upload your dataset zip file (archive (2).zip):
#      <input type="file" id="files-f9a75028-0a74-49c3-b528-4e20876a5230" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9a75028-0a74-49c3-b528-4e20876a5230">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Upload file "archive.zip"
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4dc7b113-0f8e-4162-8b1e-4fd16c22509c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4dc7b113-0f8e-4162-8b1e-4fd16c22509c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## DATA VERSION 2 ON GD
# Install gdown (only needed once)
# !pip install -U gdown

# Download archive.zip from Google Drive
# !gdown --id 1koWeVQBY972pKB1ajb4sKmZPRJZPcs5t --output archive.zip

# Optional: Unzip the downloaded file
# !unzip archive.zip -d extracted_data
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1koWeVQBY972pKB1ajb4sKmZPRJZPcs5t
# From (redirected): https://drive.google.com/uc?id=1koWeVQBY972pKB1ajb4sKmZPRJZPcs5t&confirm=t&uuid=29d53fa6-176b-4518-a16c-c7c0c00d0b60
# To: /content/archive.zip
# 100% 13.4G/13.4G [03:06<00:00, 72.0MB/s]
# Archive:  archive.zip
#    creating: extracted_data/archive/
#    creating: extracted_data/archive/Effect_of_tampering_on_decrypted_frames/
#    creating: extracted_data/archive/Effect_of_tampering_on_decrypted_frames/lowercase/
#    creating: extracted_data/archive/Effect_of_tampering_on_decrypted_frames/lowercase/Dynamic/
#    creating: extracted_data/archive/Effect_of_tampering_on_decrypted_frames/lowercase/Dynamic/Frames/
# ...

# %%
##Step 3: Explore Dataset
### Use OpenCV to check the video files
import cv2
video = cv2.VideoCapture("path/to/video.mp4")
ret, frame = video.read()
if ret:
    cv2.imshow("Frame", frame)
    cv2.waitKey(0)

# %%
# PHASE 2: Install dependencies & initialize

# STEP 1: Install dependencies
# !pip install tensorflow web3 opencv-python matplotlib

# STEP 2: Import required libraries
import os
import cv2
import numpy as np
import hashlib
import json
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LSTM, TimeDistributed
from tensorflow.keras.optimizers import Adam
from web3 import Web3
from IPython.display import display, HTML

# %%
# This is where the 'contract_abi.json' that was save from remix
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-abfa6b93-d021-4efe-9038-64f66f7ef777" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abfa6b93-d021-4efe-9038-64f66f7ef777">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from web3 import Web3
import json

# ✅ Step 1: Connect to Ganache
w3 = Web3(Web3.HTTPProvider("http://127.0.0.1:7545"))

# ✅ Step 2: Confirm connection (use is_connected in newer web3.py)
print("Connected to Ganache:", w3.is_connected())  # ✅ Should be True

# ✅ Step 3: Set default account (Ganache account #1)
w3.eth.default_account = w3.eth.accounts[0]

# ✅ Step 4: Load ABI
with open('contract_abi.json') as f:
    contract_abi = json.load(f)

# ✅ Step 5: Set contract address (from Remix)
contract_address = '0x33790f39AC0b6B547699F234FaB3aCf7012a5f21'

# ✅ Step 6: Connect to contract
contract = w3.eth.contract(address=contract_address, abi=contract_abi)

# ✅ Step 7: Store and retrieve a hash
tx_hash = contract.functions.storeHash("abc123", "Walk_Original").transact()
w3.eth.wait_for_transaction_receipt(tx_hash)

stored_hash = contract.functions.getHash("Walk_Original").call()
print("Stored Hash on Blockchain:", stored_hash)
# Out:
# Connected to Ganache: False
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...

# %%
# Step: Web3 Connection Code (Colab)

from web3 import Web3
import json

# ✅ Step 1: Connect to Ganache
# In a Colab environment, connecting directly to 127.0.0.1:7545 (your local machine)
# is not possible unless you have set up some form of tunneling or port forwarding.
# Colab runs on Google's infrastructure, not your local machine.
#
# If you are using Ganache-cli on your local machine, you might need to expose it
# to the internet or use a service like ngrok to create a public URL.
#
# Alternatively, for testing purposes in Colab, you might consider:
# 1. Using a hosted service like Infura or Alchemy (requires an API key and connecting to a public network like Sepolia or Ethereum Mainnet)
# 2. Using a simulated blockchain environment within Colab (more complex setup, potentially using py-evm)
#
# Assuming you have a way for Colab to reach your Ganache instance (e.g., ngrok), the code below connects to it.
# If not, this connection will fail.
w3 = Web3(Web3.HTTPProvider("http://127.0.0.1:7545"))

# ✅ Step 2: Confirm connection
# The correct method to check connection is is_connected()
print("Connected to Ganache:", w3.is_connected())  # Should be True if connection is successful

# If the connection fails, the following lines will also likely raise errors.
# You might want to add error handling here.

# ✅ Step 3: Set default account (first Ganache account)
# This will only work if the connection was successful and w3.eth.accounts is populated
if w3.is_connected():
    try:
        w3.eth.default_account = w3.eth.accounts[0]
        print(f"Default account set to: {w3.eth.default_account}")
    except IndexError:
        print("Error: Could not get accounts from Ganache. Is Ganache running and connected?")
    except Exception as e:
        print(f"An unexpected error occurred while setting the default account: {e}")
else:
    print("Cannot set default account: Not connected to Ganache.")


# ✅ Step 4: Load the ABI from the uploaded JSON file
# This assumes 'contract_abi.json' was successfully uploaded in the previous cell
try:
    with open('contract_abi.json') as f:
        contract_abi = json.load(f)
    print("Contract ABI loaded successfully.")
except FileNotFoundError:
    print("Error: 'contract_abi.json' not found. Please ensure it was uploaded.")
except json.JSONDecodeError:
    print("Error: Could not decode JSON from 'contract_abi.json'. Please check the file format.")
except Exception as e:
    print(f"An unexpected error occurred while loading the ABI: {e}")


# ✅ Step 5: Set your deployed contract address
contract_address = '0x33790f39AC0b6B547699F234FaB3aCf7012a5f21'  # Replace with yours if different
print(f"Contract address set to: {contract_address}")

# ✅ Step 6: Connect to the contract
# This requires both a successful connection to Ganache and the loaded ABI
contract = None
if w3.is_connected() and 'contract_abi' in locals():
    try:
        contract = w3.eth.contract(address=contract_address, abi=contract_abi)
        print("Connected to the contract.")
    except Exception as e:
        print(f"An error occurred while connecting to the contract: {e}")
else:
    if not w3.is_connected():
        print("Cannot connect to contract: Not connected to Ganache.")
    if 'contract_abi' not in locals():
        print("Cannot connect to contract: Contract ABI not loaded.")


# ✅ Step 7: Test store and get video hash
# This step requires a connected contract and a valid default account
if contract and w3.eth.default_account:
    try:
        print("Attempting to store and retrieve video hash...")
        tx_hash = contract.functions.storeHash("abc123", "Walk_Original").transact()
        print(f"Transaction sent with hash: {tx_hash.hex()}")
        receipt = w3.eth.wait_for_transaction_receipt(tx_hash)
        print("Transaction confirmed.")

        stored_hash = contract.functions.getHash("Walk_Original").call()
        print("Stored Hash on Blockchain:", stored_hash)
    except Exception as e:
        print(f"An error occurred during the transaction or call: {e}")
        print("Please check if Ganache is running, the default account has sufficient funds, and the contract address is correct.")
else:
    print("Skipping contract interaction: Contract not connected or default account not set.")
# Out:
# Connected to Ganache: False
# Cannot set default account: Not connected to Ganache.
# Contract ABI loaded successfully.
# Contract address set to: 0x33790f39AC0b6B547699F234FaB3aCf7012a5f21
# Cannot connect to contract: Not connected to Ganache.
# Skipping contract interaction: Contract not connected or default account not set.

# %%
# ✅ Updated:
contract_address = "0xfD6d85708cdE6Fecf678cB10f1CE27FF9579a30b"

# %%
from web3 import Web3
import json

# Connect to Ganache
w3 = Web3(Web3.HTTPProvider("http://127.0.0.1:7545"))
print("Connected:", w3.is_connected())

# Set default account (first Ganache account)
w3.eth.default_account = w3.eth.accounts[0]

# Load the contract ABI (make sure you uploaded contract_abi.json)
with open('contract_abi.json') as f:
    contract_abi = json.load(f)

# ✅ Paste your new contract address here
contract_address = "0xfD6d85708cdE6Fecf678cB10f1CE27FF9579a30b"

# Connect to the contract
contract = w3.eth.contract(address=contract_address, abi=contract_abi)

# Store a test hash
tx = contract.functions.storeHash("abc123", "Walk_Original").transact()
w3.eth.wait_for_transaction_receipt(tx)

# Retrieve it from blockchain
stored_hash = contract.functions.getHash("Walk_Original").call()
print("Stored Hash:", stored_hash)
# Out:
# Connected: False
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...

# %%
import cv2
video = cv2.VideoCapture("path/to/video.mp4")
ret, frame = video.read()
if ret:
    cv2.imshow("Frame", frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()  # Add this to prevent hangs
